# %% [markdown]
# <a href="https://colab.research.google.com/github/Wenypb/Simulacion/blob/main/TAREA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Crear una nueva figura
plt.figure(figsize=(8, 4))

# Configuración de la nota
plt.text(0.5, 0.5, "Sé que estamos lejos \n y no puedo verte,\n pero esto es para ti,\n te mereces lo mejor \n  y en este momento \n solo te puedo regalar \n un carrito programado \n espero te guste  \n se que no es mucho \n pero es con todo mi amor.",
         fontsize=16, ha='center', va='center', color="ghostwhite", weight='bold',
         bbox=dict(facecolor='blue', boxstyle='round,pad=1'))

# Configuraciones del gráfico
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.axis('off')  # Ocultar ejes
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
import matplotlib.pyplot as plt
import numpy as np

def dibujar_llantas_y_grafico():
    # Crear una nueva figura
    fig, ax = plt.subplots(figsize=(10, 6))
    ax.set_facecolor('lightcyan')

    x=[-20,-20,0,35,35,15,15,12.5,10,10,55,60,65,65,-20]
    y=[-20,100,115,115,100,100,102,103,102,95,95,100,100,-20,-20]
    plt.plot(x, y, color="blue",linewidth=5)
    ax.fill(x, y, color='skyblue')  # Rellenar el área
    x=[-17,-17,62,62,-17]
    y=[74,89,89,74,74]
    plt.plot(x, y, color="ghostwhite",linewidth=3)
    ax.fill(x, y, color='red')  # Rellenar el área
    # Dibujar el texto en cursiva
    ax.text(22, 65, 'Me encantaria recorrer', fontsize=10,weight='bold', font="italic",
            ha='center', va='center', color='black')
    ax.text(22, 60, "cada kilometro", fontsize=10, weight='bold', font="italic",
            ha='center', va='center', color='black')
    ax.text(22, 55 ,'de tu mano', fontsize=10, weight='bold', font="italic",
            ha='center', va='center', color='black')
    ax.text(40, 40, 'TE AMO', fontsize=15,weight='bold', font="style",
            ha='center', va='center', color='black')
    ax.text(40, 30, 'AMOR MIO', fontsize=15,weight='bold', font="style",
            ha='center', va='center', color='black')
    ax.text(40, -10, 'VOLKSWAGEN GOLF GTI', fontsize=5,weight='bold', font="style",
            ha='center', va='center', color='black')
    ax.text(-10, 80, 'H', fontsize=25, weight='bold',fontstyle='italic',
            ha='center', va='center', color='yellow')
    ax.text(-1, 80, 'O', fontsize=20, weight='bold',fontstyle='italic',
            ha='center', va='center', color='yellow')
    ax.text(5, 80, 'T', fontsize=20, weight='bold', fontstyle='italic',
            ha='center', va='center', color='yellow')
    ax.text(21, 80, 'W', fontsize=25, weight='bold', fontstyle='italic',
            ha='center', va='center', color='yellow')
    ax.text(31, 80, 'H', fontsize=20, weight='bold',fontstyle='italic',
            ha='center', va='center', color='yellow')
    ax.text(38, 80, 'E', fontsize=20,weight='bold',fontstyle='italic',
            ha='center', va='center', color='yellow')
    ax.text(44, 80, 'E', fontsize=20, weight='bold',fontstyle='italic',
            ha='center', va='center', color='yellow')
    ax.text(50, 80, 'L', fontsize=20,weight='bold', fontstyle='italic',
            ha='center', va='center', color='yellow')
    ax.text(56, 80, 'S', fontsize=20,weight='bold', fontstyle='italic',
            ha='center', va='center', color='yellow')
    # Parámetros para la ecuación del corazón
    t = np.linspace(0, 2*np.pi, 1000)
    x = 16 * np.sin(t)**3
    y = 13 * np.cos(t) - 5 * np.cos(2*t) - 2 * np.cos(3*t) - np.cos(4*t)

    # Crear la figura del corazón
    plt.plot(x, y, label='Corazón',color="snow",linewidth=2)
    # Datos para el gráfico
    x = [-5, -5.2, -5, -10.5, -10.7, -10.5, -10.5, -11.8, -11.5, -10, -8.5, 8,
         15, 19.8, 23, 32, 43, 50, 50.2, 50, 51.2, 51.5, 50.5, 46, 46.2,
         46, 36, 35.8, 36, 5, 5.2, 5, -5]
    y = [0, -2.5, -4.3, -4, -3.5, -2.5, -3, 2, 2.8, 3.9, 6.7, 10,
         13.8, 15.8, 16.2, 16.2, 16, 9, 7, 4, 2.5, 1, -4, -4.5,
         -2.5, 0, 0, -2.5, -4, -4, -2.5, 0, 0]

    # Graficar la línea
    plt.plot(x, y, color="black")
    # Pintar el área definida por los puntos en azul marino
    ax.fill(x, y, color='b')  # Rellenar el área
    # Graficar la línea
    circulo_pequeno = plt.Circle((28, 7), 0.8, color='grey')  # Círculo pequeño
    ax.add_artist(circulo_pequeno)
    plt.plot(x, y, color="black")
    w=[48,50]
    z=[7,7]
    plt.plot(w, z, color="black")
    w=[45.2,48,48.2,48,41.5]
    z=[2.5,7,8,9,16]
    plt.plot(w, z, color="black")
    w=[-5.2,-10.5]
    z=[-2.5,-2.5]
    plt.plot(w, z, color="black")
    w=[-10,-5.5,-4.2]
    z=[3.8,3.8,2.7]

    plt.plot(w, z, color="black")
    w=[-10.5,-10.2,-8.7]
    z=[3.5,5.3,6.7]
    plt.plot(w, z, color="black")
    ax.fill(w, z, color='gold')  # Rellenar el área
    w=[8,7.7,7.4,7.1,7.4,7.7,8]
    z=[10,8,6,4,2,0,-3]
    plt.plot(w, z, color="black")
    w=[5.2,35.8]
    z=[-3,-3]
    plt.plot(w, z, color="black")
    w=[7.5,33,33.4,33,7.5]
    z=[2.8,2.8,2.4,2,2]
    ax.fill(w, z, color='black')  # Rellenar el área
    plt.plot(w, z, color="black")
    w=[11,10.5,10.5,15,20,20.3,30.1,30.4,28.5,11]
    z=[8.5,9,9.7,12,14.5,14.5,14.5,14.1,8.5,8.5]
    ax.fill(w, z, color='black')  # Rellenar el área
    plt.plot(w, z, color="black")
    w=[13,28,29.7,29.4,20,13,13]
    z=[9,9,13.6,14,14,10.5,9]
    ax.fill(w, z, color='lightblue')  # Rellenar el área
    plt.plot(w, z, color="black")
    w=[26.5,29]
    z=[7,7]
    plt.plot(w, z, color="black",linewidth=4)
    w=[32.5,30,30,29,28]
    z=[16,8.5,2,-2,-3]
    plt.plot(w, z, color="black")
    w=[31.5,33.2,33.5,39,43,42.8,31.5]
    z=[8.5,14.1,14.5,14.3,9,8.5,8.5]
    ax.fill(w, z, color='lightblue')  # Rellenar el área
    plt.plot(w, z, color="black")
    w=[23,31,31,25]
    z=[16.2,18,17.8,16.2]
    ax.fill(w, z, color='black')  # Rellenar el área
    plt.plot(w, z, color="black")
    w=[43,45,44]
    z=[16,16,15]
    ax.fill(w, z, color='black')  # Rellenar el área
    plt.plot(w, z, color="black")
    w=[23,31,31,25]
    z=[16.2,18,17.8,16.2]
    plt.plot(w, z, color="black")
    w=[48.2,50]
    z=[8,8]
    plt.plot(w, z, color="black")
    w=[46.5,50]
    z=[4.5,4.5]
    plt.plot(w, z, color="black")
    w=[47.5,50]
    z=[6,6]
    plt.plot(w, z, color="black")
    w=[48.2,50,50,46.5,47.5,48.2]
    z=[8,8,4.5,4.5,6,8]
    plt.plot(w, z, color="black")
    ax.fill(w, z, color='red')  # Rellenar el área
    # Configuraciones del gráfico
    ax.set_xlim(-30,70)  # Ajustar límites para mostrar todo
    ax.set_ylim(-30,120)
    ax.set_aspect('equal')
    ax.axis('off')  # Ocultar ejes
    # Función para dibujar una llanta
    def dibujar_llanta(centro_x, centro_y):
        llanta = plt.Circle((centro_x, centro_y), 5, color='black')  # Llanta
        ax.add_artist(llanta)
        rin = plt.Circle((centro_x, centro_y), 4, color='silver')  # Rin
        ax.add_artist(rin)
        num_tuercas = 6
        for i in range(num_tuercas):
            angle = 2 * np.pi * i / num_tuercas
            tuerca_x = centro_x + 0.9 * 4 * np.cos(angle)
            tuerca_y = centro_y + 0.9 * 4 * np.sin(angle)
            ax.plot(tuerca_x, tuerca_y, 'o', color='black', markersize=6)

    # Dibujar llantas
    dibujar_llanta(0, 0)
    dibujar_llanta(41, 0)
    def dibujar_llanta(centro_x, centro_y):
        # Llanta con diámetro 7.5 (radio 3.75)
        llanta = plt.Circle((centro_x, centro_y), 9, color="blue", ec='blue')  # Llanta
        ax.add_artist(llanta)

        # Rin con diámetro 6.5 (radio 3.25)
        rin = plt.Circle((centro_x, centro_y), 7.5, color='gray', ec='blue')  # Rin
        ax.add_artist(rin)

    # Dibujar la rueda en el centro (11, 32)
    dibujar_llanta(0, 32)
    # Mostrar el gráfico
    w=[-6,-2,0,2,6,5,2,1,-1,-2,-5,-6]
    z=[35,27,31,27,35,35,29,32,32,29,35,35]
    plt.plot(w, z, color="blue")
    ax.fill(w, z, color='blue')  # Rellenar el área
    w=[-3,-1,1,3,2,0,-2]
    z=[38,33,33,38,38,33.5,38]
    plt.plot(w, z, color="blue")
    ax.fill(w, z, color='blue')  # Rellenar el área
    plt.show()

# Llamar a la función para dibujar las llantas y el gráfico
dibujar_llantas_y_grafico()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'italic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'italic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'italic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'italic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'style' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'style' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'style' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'style' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'style' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'italic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'italic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'italic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'italic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'italic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'italic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'italic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'style' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'style' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'style' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'style' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'style' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'style' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'style' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'style' not found.
