# %% [markdown]
# <a href="https://colab.research.google.com/github/Wenypb/Simulacion/blob/main/Untitled45.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def f(x,mu,std):
  return (1/np.sqrt(2*np.pi*std**2))*np.exp(-(x-mu)**2/(2*std**2))

# %%
mu=0.2
sigma=0.1

# %%
delta=0.5

# %%
n=50000
x=np.zeros(n)
x[0]=0
acept=0
for i in range(0,n-1):
  y=x[i]+np.random.uniform(-delta,delta)
  if np.random.rand()<min(1,f(y,mu,sigma)/f(x[i],mu,sigma)):
    x[i+1]=y
    acept+=1
  else:
    x[i+1]=x[i]
print("La aceptacion fue del",acept/n*100,"%")
# Out:
# La aceptacion fue del 31.69 %

# %%
plt.hist(x,density=True,bins=30)
xs=np.linspace(-1,1,100)
plt.plot(xs,f(xs,mu,sigma))

# %%
m=np.mean(x)
d=np.std(x)
print(m,d)
# Out:
# 0.19987842007412798 0.1007621232192247

# %%
plt.plot(x[0:100])

# %%
def f(x,landa):
  return ((np.exp(-landa))*(landa**x)/math.factorial(x))

# %%
delta=0.5
landa=0.3

# %%
n=50000
x=np.zeros(n)
x[0]=0
acept=0
for i in range(0,n-1):
  y=x[i]+np.random.uniform(-delta,delta)
  if np.random.rand()<min(1,f(y,landa)/f(x[i],landa)):
    x[i+1]=y
    acept+=1
  else:
    x[i+1]=x[i]
print("La aceptacion fue del",acept/n*100,"%")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-a0d23e3780fe> in <cell line: 5>()
#       5 for i in range(0,n-1):
#       6   y=x[i]+np.random.uniform(-delta,delta)
# ----> 7   if np.random.rand()<min(1,f(y,landa)/f(x[i],landa)):
#       8     x[i+1]=y
#       9     acept+=1
#
# <ipython-input-87-b0b107a5c722> in f(x, landa)
#       1 def f(x,landa):
# ----> 2   return ((np.exp(-landa))*(landa**x)/math.factorial(x))
#
# TypeError: 'numpy.float64' object cannot be interpreted as an integer

# %% [markdown]
# Hacer el procedimiento con chi-cuadrada
